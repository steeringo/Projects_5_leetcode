# %%
import seaborn as sns
import pandas as pd
import numbers as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing and checking data

# %%
df = pd.read_csv("D:\Programowanie\Programming\kaggle_data\Car Dataset/Car data.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Rafal\AppData\Local\Temp\ipykernel_18532\994972744.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("D:\Programowanie\Programming\kaggle_data\Car Dataset/Car data.csv")

# %%
df.head(10)
# Out:
#                Name  Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  \
# 0     Mahindra Thar             11.35             17.60         15.20  1497
# 1      Maruti Swift              6.49              9.60         24.80  1197
# 2  Mahindra Scorpio             13.62             17.42         22.00  2184
# 3        Tata Punch              6.13             10.20         20.09  1199
# 4     Hyundai Creta             11.00             20.15         17.40  1497
# 5   Mahindra XUV700             13.99             26.04         15.00  1999
# 6        Tata Nexon              8.00             15.80         17.44  1199
# 7     Maruti Brezza              8.34             14.14         17.38  1462
# 8  Mahindra XUV 3XO              7.49             15.49         18.89  1197
# 9   Toyota Fortuner             33.43             51.44         10.00  2694
#
#    Seats  Variants     Type  Ex-Showroom Price       RTO  Insurance  Other  \
# ...

# %%
df.describe()
# Out:
#        Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)           CC  \
# count         21.000000         21.000000     21.000000    21.000000
# mean          15.129048         42.762857     17.781429  1690.857143
# std           19.837477         77.051152      3.886819   536.710377
# min            2.360000          9.600000      9.200000  1197.000000
# 25%            7.490000         13.030000     16.000000  1199.000000
# 50%            9.790000         17.420000     17.440000  1497.000000
# 75%           13.850000         26.040000     20.090000  1997.000000
# max           97.000000        285.000000     24.800000  2997.000000
#
#            Seats    Variants  Ex-Showroom Price           RTO      Insurance  \
# count  21.000000   21.000000       2.100000e+01  2.100000e+01      21.000000
# mean    5.571429   22.190476       2.639533e+06  2.894617e+05  116669.697905
# std     1.075706   21.404717       5.187114e+06  6.419840e+05  205833.811082
# ...

# %%
df.dtypes
# Out:
# Name                  object
# Min Price (Lakh)     float64
# Max Price (Lakh)     float64
# Range (kmpl)         float64
# CC                     int64
# Seats                  int64
# Variants               int64
# Type                  object
# Ex-Showroom Price      int64
# RTO                  float64
# Insurance            float64
# Other                  int64
# Onroad Price          object
# dtype: object

# %%
df.shape
# Out:
# (21, 13)

# %% [markdown]
# ## Preprocessing

# %%
df.drop(['Name', 'Type'], axis=1, inplace= True)
df.head()
# Out:
#    Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  Seats  Variants  \
# 0             11.35             17.60         15.20  1497      4        19
# 1              6.49              9.60         24.80  1197      5        11
# 2             13.62             17.42         22.00  2184      7         4
# 3              6.13             10.20         20.09  1199      5        25
# 4             11.00             20.15         17.40  1497      5        28
#
#    Ex-Showroom Price       RTO  Insurance  Other Onroad Price
# 0            1430000  143000.0    84367.0  14300    16,71,667
# 1             649000   46240.0    27791.0   5485     7,28,516
# 2            1361600  175000.0    85943.0  27532    16,50,075
# 3             612900   42903.0    35311.0      0     6,91,114
# 4            1099900  116863.0    45300.0  11599    12,73,662

# %%
df['Onroad Price'] = df['Onroad Price'].astype(str)
df['Onroad Price'] = df['Onroad Price'].str.replace(',', '')
df['Onroad Price'] = df['Onroad Price'].astype(int)
df
# Out:
#     Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  Seats  Variants  \
# 0              11.35             17.60         15.20  1497      4        19
# 1               6.49              9.60         24.80  1197      5        11
# 2              13.62             17.42         22.00  2184      7         4
# 3               6.13             10.20         20.09  1199      5        25
# 4              11.00             20.15         17.40  1497      5        28
# 5              13.99             26.04         15.00  1999      5        49
# 6               8.00             15.80         17.44  1199      5       100
# 7               8.34             14.14         17.38  1462      5        15
# 8               7.49             15.49         18.89  1197      5        25
# 9              33.43             51.44         10.00  2694      7         7
# 10              9.79             10.91         16.00  1493      7         3
# ...

# %%
df['Average Price'] = (df['Min Price (Lakh)']+df['Max Price (Lakh)'])/2
df
# Out:
#     Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  Seats  Variants  \
# 0              11.35             17.60         15.20  1497      4        19
# 1               6.49              9.60         24.80  1197      5        11
# 2              13.62             17.42         22.00  2184      7         4
# 3               6.13             10.20         20.09  1199      5        25
# 4              11.00             20.15         17.40  1497      5        28
# 5              13.99             26.04         15.00  1999      5        49
# 6               8.00             15.80         17.44  1199      5       100
# 7               8.34             14.14         17.38  1462      5        15
# 8               7.49             15.49         18.89  1197      5        25
# 9              33.43             51.44         10.00  2694      7         7
# 10              9.79             10.91         16.00  1493      7         3
# ...

# %% [markdown]
# ## Analysing data

# %% [markdown]
# **Heatmap of correlation**

# %%
corr_matrix = df.corr()
plt.figure(figsize=(13,13))
sns.heatmap(corr_matrix, annot=True ,cmap='coolwarm', fmt= '.2f')
#sns.heatmap(corr_matrix, cmap='coolwarm', fmt= '.2f')
plt.show()

# %%
plt.hist(corr_matrix['Average Price'], bins= 12)
# Out:
# (array([1., 0., 0., 1., 1., 0., 0., 0., 1., 0., 6., 2.]),
#  array([-0.67256345, -0.53318317, -0.39380288, -0.25442259, -0.1150423 ,
#          0.02433798,  0.16371827,  0.30309856,  0.44247885,  0.58185914,
#          0.72123942,  0.86061971,  1.        ]),
#  <BarContainer object of 12 artists>)
